# %% [markdown]
# # CERT r4.2 Exploratory Data Analysis
# Exploration only — nothing in this notebook is production code.
# Covers: event volume by type, user activity distributions, label imbalance, off-hours patterns.
